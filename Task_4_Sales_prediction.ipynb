# %% [markdown]
# *   **Task  - 4 : Sales Prediction Using Python
# Name : Patel Riya Dharmendrabhai
# Program : M.sc Data Science(sem-1)**

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Getting CSV file data

# %%
sales = pd.read_csv("/content/advertising.csv")
sales
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
sales.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sales.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
sales.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# # Getting information of data

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# # Checking Shape of data in terms of rows and columns

# %%
sales.shape
# Out:
# (200, 4)

# %%
sales.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %% [markdown]
# # Checking null values

# %%
sales.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # Pair Scatter Plots

# %%
sns.pairplot(sales , x_vars=['TV','Radio','Newspaper'] , y_vars='Sales' , size=3 , aspect=1 , kind='scatter')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(4,3))
sns.heatmap(sales.corr() , cmap='magma' , annot = True)
plt.show()

# %% [markdown]
# # Scatter plot of sales of TV

# %%
x = sales[['TV']]
y = sales['Sales']

# %%
plt.xlabel('TV')
plt.ylabel('Sales of tv')
plt.scatter(x,y)

# %% [markdown]
# # Model Train And Test

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=32)

# %%
print(xtrain)
print(ytrain)
print(xtest)
print(ytest)
# Out:
#         TV
# 156   93.9
# 154  187.8
# 153  171.3
# 197  177.0
# 185  205.0
# ..     ...
# 190   39.5
# 124  229.5
# 54   262.7
# 133  219.8
# 43   206.9
#
# [160 rows x 1 columns]
# 156    15.3
# 154    20.6
# 153    16.0
# 197    14.8
# 185    22.6
#        ...
# 190    10.8
# 124    19.7
# 54     20.2
# 133    19.6
# 43     17.9
# Name: Sales, Length: 160, dtype: float64
#         TV
# 122  224.0
# 186  139.5
# 167  206.8
# 101  296.4
# 29    70.6
# 75    16.9
# 144   96.2
# 28   248.8
# 121   18.8
# 182   56.2
# 27   240.1
# 181  218.5
# 39   228.0
# 23   228.3
# 2     17.2
# 173  168.4
# 107   90.4
# 17   281.4
# 109  255.4
# 118  125.7
# 26   142.9
# 46    89.7
# 21   237.4
# 160  172.5
# 44    25.1
# 143  104.6
# 56     7.3
# 188  286.0
# 79   116.0
# 73   129.4
# 164  117.2
# 18    69.2
# 102  280.2
# 131  265.2
# 96   197.6
# 141  193.7
# 115   75.1
# 174  222.4
# 130    0.7
# 34    95.7
# 122    16.6
# 186    10.3
# 167    17.2
# 101    23.8
# 29     10.5
# 75      8.7
# ...

# %%
#xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=44)

# %%
#print(xtrain)
#print(ytrain)
#print(xtest)
#print(ytest)

# %% [markdown]
# # Convert data types float to integer

# %%
sales.astype({'TV':'int','Radio':'int','Newspaper':'int','Sales':'int'}).dtypes
# Out:
# TV           int64
# Radio        int64
# Newspaper    int64
# Sales        int64
# dtype: object

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
ypred
# Out:
# array([19.66824404, 14.91968478, 18.7016734 , 23.73683209, 11.04778262,
#         8.03005917, 12.48639939, 21.06190403,  8.13683151, 10.23856069,
#        20.57299912, 19.35916622, 19.89302791, 19.9098867 ,  8.04691796,
#        16.54374825, 12.16046278, 22.89389257, 21.43279742, 14.14418043,
#        15.11075107, 12.1211256 , 20.42127   , 16.77415171,  8.4908661 ,
#        12.95844552,  7.49057788, 23.15239402, 13.59907955, 14.35210551,
#        13.66651471, 10.96910827, 22.82645741, 21.9835179 , 18.1846705 ,
#        17.96550622, 11.30066448, 19.57833049,  7.11968449, 12.45830141])

# %%
ytest.values
# Out:
# array([16.6, 10.3, 17.2, 23.8, 10.5,  8.7, 12.3, 18.9,  7. ,  8.7, 20.9,
#        17.2, 21.5, 20.5, 12. , 16.7, 12. , 24.4, 19.8, 15.9, 15. , 10.6,
#        17.5, 16.4,  8.5, 10.4,  5.5, 20.9, 11. , 11. , 11.9, 11.3, 19.8,
#        17.7, 16.7, 19.2, 12.6, 16.5,  1.6, 11.9])

# %%
from sklearn.metrics import r2_score
r2 = r2_score(ytest,ypred)
r2
# Out:
# 0.8145017428473121

# %% [markdown]
# **Value of r2 score is 0.81**

# %%
plt.figure(figsize=(5,4))
plt.xlabel('TV')
plt.ylabel('Sales of TV')
plt.title('Linear Regression Model')
plt.plot(xtrain,model.predict(xtrain),color='red',label='line of regression')
plt.scatter(xtrain,model.predict(xtrain),color='green',label='Actual Data')
plt.scatter(xtrain,ytrain,label='predicted data')
plt.legend()
plt.show()
